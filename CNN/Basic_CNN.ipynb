# %%
# Copyright 2018, JinYoung Kim Softcomputing LAB all rights reserved.
# %matplotlib inline
from keras.models import *
from keras.layers import *
from keras.datasets import *
from keras.utils import *
from keras.callbacks import *
from keras import backend as K

from sklearn.metrics import confusion_matrix
from sklearn.manifold import TSNE
import numpy as np
from matplotlib import pyplot as plt

# %%
def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion matrix', cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        cm *= 1000
        cm = np.round(cm)
        cm /= 1000
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            plt.text(j, i, cm[i, j],
            horizontalalignment="center",
            color="white" if cm[i, j] > thresh else "black")
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %% [markdown]
# # Load data

# %% [markdown]
# ## Download MNIST dataset

# %%
(X_train, Y_train), (X_test, Y_test) = mnist.load_data()
print(X_train.shape, Y_train.shape)
print(X_test.shape, Y_test.shape)
# Out:
# (60000, 28, 28) (60000,)
# (10000, 28, 28) (10000,)

# %% [markdown]
# ## Visualization

# %%
plt.figure(figsize=(13,13))
for i in range(np_utils.to_categorical(Y_train).shape[1]):
    for j in range(10):
        plt.subplot(10, np_utils.to_categorical(Y_train).shape[1], i * 10 + j + 1)
        plt.imshow(X_train[Y_train==i][j], cmap='gray')
        plt.axis('off')
        plt.title(str(i))
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Pre-processing data

# %%
X_train, X_test = X_train / (2. / 255.) - 1, X_test / (2. / 255.) - 1
X_train = np.expand_dims(X_train, axis=-1)
X_test = np.expand_dims(X_test, axis=-1)
Y_train, Y_test = np_utils.to_categorical(Y_train), np_utils.to_categorical(Y_test)
print(X_train.shape, Y_train.shape)
print(X_test.shape, Y_test.shape)
# Out:
# (60000, 28, 28, 1) (60000, 10)
# (10000, 28, 28, 1) (10000, 10)

# %% [markdown]
# # Build Basic NN

# %%
def Basic_NN(hidden_units, n_class, activation='tanh', dropout = False, dropout_rate = -1, batchnormalization = False):
    if dropout and dropout_rate < 0:
        print('If you use dropout, specify dropout rate between 0 and 1')
        return -1
    def _f(inp):
        x = inp
        for i in range(len(hidden_units)):
            x = Dense(hidden_units[i], activation = activation)(x)
            if batchnormalization:
                x = BatchNormalization()(x)
            if dropout:
                x = Dropout(dropout_rate)(x)
        out = Dense(n_class, activation='softmax')(x)
        return out
    return _f

def Basic_CNN(hidden_units, nch, filter_size, loop, n_class, activation='tanh', dropout = False, dropout_rate = -1, batchnormalization = False):
    if dropout and dropout_rate < 0:
        print('If you use dropout, specify dropout rate between 0 and 1')
        return -1
    def _f(inp):
        x = inp
        for i in range(loop):
            x = Conv2D(nch // 2**(loop - i + 1), filter_size, activation = activation, padding = 'same')(x)
            if batchnormalization:
                x = BatchNormalization()(x)
            if dropout:
                x = Dropout(dropout_rate)(x)
            x = MaxPool2D((2,2))(x)
        x =  Flatten()(x)
        out = Basic_NN(hidden_units, n_class, activation, dropout, dropout_rate, batchnormalization)(x)
        return out
    return _f

# %% [markdown]
# ## Params

# %%
# The number of hidden layers = len(hidden_units)
# The number of nodes in i-th hidden layers = hidden_units[i-1]
hidden_units = [512, 512]

# Size and the number of kernels
filter_size = (3,3)
nch = 64

# The number of iteration (Conv-Pool)
loop = 3

# The number of classes
n_class = Y_train.shape[1]

# Activation functions: 'tanh' (default), 'linear', 'relu', 'elu', 'selu', 'sigmoid', etc.
activation = 'tanh'

# Several layers
dropout = True
dropout_rate = 0.25
batchnormalization = True

# Optimizers: 'sgd', 'rmsprop', 'adadelta', 'adam'
optimizer = 'adam'

# Params for training
epochs = 100
batch_size = 512

# Callbacks
callbacks = [EarlyStopping(patience = 5, verbose = 1),
            ReduceLROnPlateau(patience = 3, verbose = 1)]

# %% [markdown]
# ## Construct model

# %%
inp = Input(X_train.shape[1:])
out = Basic_CNN(hidden_units, nch, filter_size, loop, n_class, activation, dropout, dropout_rate, batchnormalization)(inp)

model = Model(inp, out)
model.compile(optimizer = optimizer, loss = 'categorical_crossentropy', metrics=['acc'])
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         (None, 28, 28, 1)         0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 28, 28, 4)         40
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 28, 28, 4)         16
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 28, 28, 4)         0
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 14, 14, 4)         0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 14, 14, 8)         296
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 14, 14, 8)         32
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 14, 14, 8)         0
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 7, 7, 8)           0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 7, 7, 16)          1168
# _________________________________________________________________
# batch_normalization_21 (Batc (None, 7, 7, 16)          64
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 7, 7, 16)          0
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 3, 3, 16)          0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 144)               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 512)               74240
# _________________________________________________________________
# batch_normalization_22 (Batc (None, 512)               2048
# _________________________________________________________________
# dropout_22 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_14 (Dense)             (None, 512)               262656
# _________________________________________________________________
# batch_normalization_23 (Batc (None, 512)               2048
# _________________________________________________________________
# dropout_23 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_15 (Dense)             (None, 10)                5130
# =================================================================
# Total params: 347,738
# Trainable params: 345,634
# Non-trainable params: 2,104
# _________________________________________________________________

# %% [markdown]
# ## Train

# %%
history = model.fit(X_train, Y_train, epochs = epochs, batch_size = batch_size, verbose = 2,
                   validation_data = [X_test, Y_test], callbacks = callbacks)
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/100
#  - 5s - loss: 0.8413 - acc: 0.7306 - val_loss: 1.0332 - val_acc: 0.7320
# Epoch 2/100
#  - 2s - loss: 0.4123 - acc: 0.8630 - val_loss: 0.6809 - val_acc: 0.8144
# Epoch 3/100
#  - 2s - loss: 0.3062 - acc: 0.8977 - val_loss: 0.3819 - val_acc: 0.8887
# Epoch 4/100
#  - 2s - loss: 0.2580 - acc: 0.9145 - val_loss: 0.2703 - val_acc: 0.9192
# Epoch 5/100
#  - 2s - loss: 0.2223 - acc: 0.9263 - val_loss: 0.2430 - val_acc: 0.9245
# Epoch 6/100
#  - 2s - loss: 0.2009 - acc: 0.9336 - val_loss: 0.2105 - val_acc: 0.9353
# Epoch 7/100
#  - 2s - loss: 0.1815 - acc: 0.9411 - val_loss: 0.1657 - val_acc: 0.9454
# Epoch 8/100
#  - 2s - loss: 0.1668 - acc: 0.9445 - val_loss: 0.1260 - val_acc: 0.9575
# Epoch 9/100
#  - 2s - loss: 0.1532 - acc: 0.9495 - val_loss: 0.1153 - val_acc: 0.9608
# Epoch 10/100
#  - 2s - loss: 0.1444 - acc: 0.9520 - val_loss: 0.1091 - val_acc: 0.9649
# Epoch 11/100
#  - 2s - loss: 0.1378 - acc: 0.9540 - val_loss: 0.0972 - val_acc: 0.9698
# Epoch 12/100
#  - 2s - loss: 0.1340 - acc: 0.9559 - val_loss: 0.1045 - val_acc: 0.9659
# Epoch 13/100
#  - 2s - loss: 0.1335 - acc: 0.9556 - val_loss: 0.0888 - val_acc: 0.9727
# Epoch 14/100
#  - 2s - loss: 0.1230 - acc: 0.9590 - val_loss: 0.1005 - val_acc: 0.9688
# Epoch 15/100
#  - 2s - loss: 0.1218 - acc: 0.9601 - val_loss: 0.1130 - val_acc: 0.9623
# Epoch 16/100
#  - 2s - loss: 0.1128 - acc: 0.9625 - val_loss: 0.0882 - val_acc: 0.9708
# Epoch 17/100
#  - 2s - loss: 0.1089 - acc: 0.9637 - val_loss: 0.0814 - val_acc: 0.9750
# Epoch 18/100
#  - 2s - loss: 0.1052 - acc: 0.9655 - val_loss: 0.0990 - val_acc: 0.9697
# Epoch 19/100
#  - 2s - loss: 0.1045 - acc: 0.9658 - val_loss: 0.1006 - val_acc: 0.9683
# Epoch 20/100
#  - 2s - loss: 0.1035 - acc: 0.9665 - val_loss: 0.1010 - val_acc: 0.9679
# Epoch 21/100
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#  - 2s - loss: 0.0969 - acc: 0.9680 - val_loss: 0.1065 - val_acc: 0.9682
# Epoch 22/100
#  - 2s - loss: 0.0918 - acc: 0.9690 - val_loss: 0.0810 - val_acc: 0.9749
# Epoch 23/100
#  - 2s - loss: 0.0876 - acc: 0.9711 - val_loss: 0.0791 - val_acc: 0.9760
# Epoch 24/100
#  - 2s - loss: 0.0851 - acc: 0.9717 - val_loss: 0.0795 - val_acc: 0.9752
# Epoch 25/100
#  - 2s - loss: 0.0849 - acc: 0.9720 - val_loss: 0.0770 - val_acc: 0.9754
# Epoch 26/100
#  - 2s - loss: 0.0859 - acc: 0.9717 - val_loss: 0.0742 - val_acc: 0.9767
# Epoch 27/100
#  - 2s - loss: 0.0825 - acc: 0.9718 - val_loss: 0.0762 - val_acc: 0.9761
# Epoch 28/100
#  - 2s - loss: 0.0843 - acc: 0.9719 - val_loss: 0.0757 - val_acc: 0.9759
# Epoch 29/100
#  - 2s - loss: 0.0830 - acc: 0.9720 - val_loss: 0.0724 - val_acc: 0.9770
# Epoch 30/100
#  - 2s - loss: 0.0815 - acc: 0.9727 - val_loss: 0.0734 - val_acc: 0.9770
# Epoch 31/100
#  - 2s - loss: 0.0825 - acc: 0.9724 - val_loss: 0.0726 - val_acc: 0.9780
# Epoch 32/100
#  - 2s - loss: 0.0819 - acc: 0.9734 - val_loss: 0.0694 - val_acc: 0.9792
# Epoch 33/100
#  - 2s - loss: 0.0812 - acc: 0.9733 - val_loss: 0.0739 - val_acc: 0.9776
# Epoch 34/100
#  - 2s - loss: 0.0810 - acc: 0.9732 - val_loss: 0.0719 - val_acc: 0.9782
# Epoch 35/100
#  - 2s - loss: 0.0768 - acc: 0.9745 - val_loss: 0.0690 - val_acc: 0.9789
# Epoch 36/100
#  - 2s - loss: 0.0765 - acc: 0.9746 - val_loss: 0.0705 - val_acc: 0.9785
# Epoch 37/100
#  - 2s - loss: 0.0748 - acc: 0.9748 - val_loss: 0.0703 - val_acc: 0.9784
# Epoch 38/100
#  - 2s - loss: 0.0756 - acc: 0.9752 - val_loss: 0.0700 - val_acc: 0.9782
# Epoch 39/100
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#  - 2s - loss: 0.0754 - acc: 0.9751 - val_loss: 0.0725 - val_acc: 0.9774
# Epoch 40/100
#  - 2s - loss: 0.0758 - acc: 0.9744 - val_loss: 0.0713 - val_acc: 0.9775
# Epoch 00040: early stopping

# %%
training_result = model.evaluate(X_train, Y_train, verbose = 0)
print ('Training loss: %.4f, acc: %.2f%%'%(training_result[0], training_result[1] * 100))
test_result = model.evaluate(X_test, Y_test, verbose = 0)
print ('Training loss: %.4f, acc: %.2f%%'%(test_result[0], test_result[1] * 100))
# Out:
# Training loss: 0.0541, acc: 98.26%
# Training loss: 0.0713, acc: 97.75%

# %% [markdown]
# ## Visualization

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend(['loss', 'val_loss'])
plt.subplot(1,2,2)
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.xlabel('epochs')
plt.ylabel('acc')
plt.legend(['acc', 'val_acc'])
plt.show()

# %%
pred = np.argmax(model.predict(X_test, verbose = 0), axis=1)
cm = confusion_matrix(np.argmax(Y_test, axis=1), pred)
plt.figure(figsize=(7,7))
plot_confusion_matrix(cm, classes = [str(i) for i in range(Y_train.shape[1])])
plt.tight_layout()
plt.show()

# %%
# Caution Below process takes long long time

# TSNE for original data
n_samples = 4000
rand_idx = np.random.randint(X_test.shape[0], size=[n_samples,])
tsne = TSNE()
tsne_output = tsne.fit_transform(np.reshape(X_test[rand_idx], (-1,X_test.shape[1] * X_test.shape[2])))

# TSNE for the second last layer's output
layer_func = K.function([model.layers[0].input, K.learning_phase()],[model.layers[-2].output])
layer_output = layer_func([X_test[rand_idx], 0])[0]
tsne = TSNE()
tsne_output2 = tsne.fit_transform(layer_output)

plt.figure(figsize=(15,7))

# plot original data
plt.subplot(1,2,1)
plt.scatter(tsne_output[:, 0], tsne_output[:,1], s = 4**2, c = np.argmax(Y_test, axis=1)[rand_idx], cmap='jet')

# plot the second last layer's output
plt.subplot(1,2,2)
plt.scatter(tsne_output2[:, 0], tsne_output2[:,1], s = 4**2, c = np.argmax(Y_test, axis=1)[rand_idx], cmap='jet')
plt.tight_layout()

plt.show()
